# %% [markdown]
# # Indexing and Slicing

# %% [markdown]
# Problem 1.Import Titanic dataset and store as the pandas dataframe with name titanic

# %%
import pandas as pd

# %%
titanic = pd.read_csv('https://github.com/YBI-Foundation/Dataset/raw/main/Titanic.csv')

# %% [markdown]
# Problem 2. Print info of titanic

# %%
titanic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1309 entries, 0 to 1308
# Data columns (total 14 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   pclass     1309 non-null   int64
#  1   survived   1309 non-null   int64
#  2   name       1309 non-null   object
#  3   sex        1309 non-null   object
#  4   age        1046 non-null   float64
#  5   sibsp      1309 non-null   int64
#  6   parch      1309 non-null   int64
#  7   ticket     1309 non-null   object
#  8   fare       1308 non-null   float64
#  9   cabin      295 non-null    object
#  10  embarked   1307 non-null   object
#  11  boat       486 non-null    object
#  12  body       121 non-null    float64
#  13  home.dest  745 non-null    object
# dtypes: float64(3), int64(4), object(7)
# memory usage: 143.3+ KB

# %% [markdown]
# Poblem 3.Print column labels

# %%
titanic.columns
# Out:
# Index(['pclass', 'survived', 'name', 'sex', 'age', 'sibsp', 'parch', 'ticket',
#        'fare', 'cabin', 'embarked', 'boat', 'body', 'home.dest'],
#       dtype='object')

# %% [markdown]
# Problem 4.Select passenger name column

# %%
titanic.name
# Out:
# 0                         Allen, Miss. Elisabeth Walton
# 1                        Allison, Master. Hudson Trevor
# 2                          Allison, Miss. Helen Loraine
# 3                  Allison, Mr. Hudson Joshua Creighton
# 4       Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
#                              ...
# 1304                               Zabour, Miss. Hileni
# 1305                              Zabour, Miss. Thamine
# 1306                          Zakarian, Mr. Mapriededer
# 1307                                Zakarian, Mr. Ortin
# 1308                                 Zimmerman, Mr. Leo
# Name: name, Length: 1309, dtype: object

# %%
type(titanic.name)
# Out:
# pandas.core.series.Series

# %% [markdown]
# Problem 5. Select passengers name column as pandas series and save as name

# %%
titanic['name']
# Out:
# 0                         Allen, Miss. Elisabeth Walton
# 1                        Allison, Master. Hudson Trevor
# 2                          Allison, Miss. Helen Loraine
# 3                  Allison, Mr. Hudson Joshua Creighton
# 4       Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
#                              ...
# 1304                               Zabour, Miss. Hileni
# 1305                              Zabour, Miss. Thamine
# 1306                          Zakarian, Mr. Mapriededer
# 1307                                Zakarian, Mr. Ortin
# 1308                                 Zimmerman, Mr. Leo
# Name: name, Length: 1309, dtype: object

# %%
name=titanic['name']

# %%
name
# Out:
# 0                         Allen, Miss. Elisabeth Walton
# 1                        Allison, Master. Hudson Trevor
# 2                          Allison, Miss. Helen Loraine
# 3                  Allison, Mr. Hudson Joshua Creighton
# 4       Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
#                              ...
# 1304                               Zabour, Miss. Hileni
# 1305                              Zabour, Miss. Thamine
# 1306                          Zakarian, Mr. Mapriededer
# 1307                                Zakarian, Mr. Ortin
# 1308                                 Zimmerman, Mr. Leo
# Name: name, Length: 1309, dtype: object

# %%
type(name)
# Out:
# pandas.core.series.Series

# %%
name.shape
# Out:
# (1309,)

# %% [markdown]
# Problem 6. Select passengers name column and save as pandas dataframe

# %%
name=titanic[['name']]

# %%
name
# Out:
#                                                  name
# 0                       Allen, Miss. Elisabeth Walton
# 1                      Allison, Master. Hudson Trevor
# 2                        Allison, Miss. Helen Loraine
# 3                Allison, Mr. Hudson Joshua Creighton
# 4     Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# ...                                               ...
# 1304                             Zabour, Miss. Hileni
# 1305                            Zabour, Miss. Thamine
# 1306                        Zakarian, Mr. Mapriededer
# 1307                              Zakarian, Mr. Ortin
# 1308                               Zimmerman, Mr. Leo
#
# [1309 rows x 1 columns]

# %%
type(name)
# Out:
# pandas.core.frame.DataFrame

# %%
name.shape
# Out:
# (1309, 1)

# %% [markdown]
# Problem 7.Select 100 th row and all columns with iloc function

# %%
titanic.iloc[100,:]
# Out:
# pclass                                                  1
# survived                                                1
# name         Duff Gordon, Sir. Cosmo Edmund ("Mr Morgan")
# sex                                                  male
# age                                                  49.0
# sibsp                                                   1
# parch                                                   0
# ticket                                           PC 17485
# fare                                              56.9292
# cabin                                                 A20
# embarked                                                C
# boat                                                    1
# body                                                  NaN
# home.dest                                  London / Paris
# Name: 100, dtype: object

# %% [markdown]
# Probllem 8. select 100th row with loc function

# %%
titanic.loc[100,:]
# Out:
# pclass                                                  1
# survived                                                1
# name         Duff Gordon, Sir. Cosmo Edmund ("Mr Morgan")
# sex                                                  male
# age                                                  49.0
# sibsp                                                   1
# parch                                                   0
# ticket                                           PC 17485
# fare                                              56.9292
# cabin                                                 A20
# embarked                                                C
# boat                                                    1
# body                                                  NaN
# home.dest                                  London / Paris
# Name: 100, dtype: object

# %% [markdown]
# Problem 9.Select all rows with columns label name and fare column with iloc function

# %%
titanic.iloc[:,[2,8]]
# Out:
#                                                  name      fare
# 0                       Allen, Miss. Elisabeth Walton  211.3375
# 1                      Allison, Master. Hudson Trevor  151.5500
# 2                        Allison, Miss. Helen Loraine  151.5500
# 3                Allison, Mr. Hudson Joshua Creighton  151.5500
# 4     Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  151.5500
# ...                                               ...       ...
# 1304                             Zabour, Miss. Hileni   14.4542
# 1305                            Zabour, Miss. Thamine   14.4542
# 1306                        Zakarian, Mr. Mapriededer    7.2250
# 1307                              Zakarian, Mr. Ortin    7.2250
# 1308                               Zimmerman, Mr. Leo    7.8750
#
# [1309 rows x 2 columns]

# %% [markdown]
# problem 10.Select all rows with loc function and column label name and fare

# %%
titanic.loc[:,['name','fare'] ]
# Out:
#                                                  name      fare
# 0                       Allen, Miss. Elisabeth Walton  211.3375
# 1                      Allison, Master. Hudson Trevor  151.5500
# 2                        Allison, Miss. Helen Loraine  151.5500
# 3                Allison, Mr. Hudson Joshua Creighton  151.5500
# 4     Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  151.5500
# ...                                               ...       ...
# 1304                             Zabour, Miss. Hileni   14.4542
# 1305                            Zabour, Miss. Thamine   14.4542
# 1306                        Zakarian, Mr. Mapriededer    7.2250
# 1307                              Zakarian, Mr. Ortin    7.2250
# 1308                               Zimmerman, Mr. Leo    7.8750
#
# [1309 rows x 2 columns]

# %%
titanic.columns
# Out:
# Index(['pclass', 'survived', 'name', 'sex', 'age', 'sibsp', 'parch', 'ticket',
#        'fare', 'cabin', 'embarked', 'boat', 'body', 'home.dest'],
#       dtype='object')

# %% [markdown]
# Problem 11 .Select row number 50th,25th,15th and column label passenger class, fare age with both loc and iloc function

# %%
titanic.loc[[50,25,15],['place','fare','age']]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-49-ea78f6854d2c> in <module>()
# ----> 1 titanic.loc[[50,25,15],['place','fare','age']]
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexing.py in __getitem__(self, key)
#     923                 with suppress(KeyError, IndexError):
#     924                     return self.obj._get_value(*key, takeable=self._takeable)
# --> 925             return self._getitem_tuple(key)
#     926         else:
#     927             # we by definition only have the 0th axis
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexing.py in _getitem_tuple(self, tup)
#    1105         # ugly hack for GH #836
#    1106         if self._multi_take_opportunity(tup):
# -> 1107             return self._multi_take(tup)
#    1108
#    1109         return self._getitem_tuple_same_dim(tup)
#
# ...

# %%
titanic.iloc[[50,25,15],[0,8,4]]
# Out:
#     pclass      fare   age
# 50       1  512.3292  58.0
# 25       1   26.0000  25.0
# 15       1   25.9250   NaN

# %% [markdown]
# Problem12. Select rows from 10th,25th, and column label passenger class, fare,age with both loc and iloc function

# %%
titanic.loc[10:25,['pclass','fare','age']]
# Out:
#     pclass      fare   age
# 10       1  227.5250  47.0
# 11       1  227.5250  18.0
# 12       1   69.3000  24.0
# 13       1   78.8500  26.0
# 14       1   30.0000  80.0
# 15       1   25.9250   NaN
# 16       1  247.5208  24.0
# 17       1  247.5208  50.0
# 18       1   76.2917  32.0
# 19       1   75.2417  36.0
# 20       1   52.5542  37.0
# 21       1   52.5542  47.0
# 22       1   30.0000  26.0
# 23       1  227.5250  42.0
# 24       1  221.7792  29.0
# 25       1   26.0000  25.0

# %% [markdown]
# Problem 13.Select rows from 10th to 15th and columns  from passenger class to age with both loc and iloc function

# %%
titanic.loc[10:15,'pclass':'age']
# Out:
#     pclass  survived                                               name  \
# 10       1         0                             Astor, Col. John Jacob
# 11       1         1  Astor, Mrs. John Jacob (Madeleine Talmadge Force)
# 12       1         1                      Aubart, Mme. Leontine Pauline
# 13       1         1                       Barber, Miss. Ellen "Nellie"
# 14       1         1               Barkworth, Mr. Algernon Henry Wilson
# 15       1         0                                Baumann, Mr. John D
#
#        sex   age
# 10    male  47.0
# 11  female  18.0
# 12  female  24.0
# 13  female  26.0
# 14    male  80.0
# 15    male   NaN

# %%
titanic.iloc[10:16,0:5]
# Out:
#     pclass  survived                                               name  \
# 10       1         0                             Astor, Col. John Jacob
# 11       1         1  Astor, Mrs. John Jacob (Madeleine Talmadge Force)
# 12       1         1                      Aubart, Mme. Leontine Pauline
# 13       1         1                       Barber, Miss. Ellen "Nellie"
# 14       1         1               Barkworth, Mr. Algernon Henry Wilson
# 15       1         0                                Baumann, Mr. John D
#
#        sex   age
# 10    male  47.0
# 11  female  18.0
# 12  female  24.0
# 13  female  26.0
# 14    male  80.0
# 15    male   NaN

# %% [markdown]
# Problem 14 Select all passenger with age equal to and more than 35 years

# %%
 
 
 
 
 
 titanic[titanic['age']>=35]
# Out:
#       pclass  survived                                             name  \
# 5          1         1                              Anderson, Mr. Harry
# 6          1         1                Andrews, Miss. Kornelia Theodosia
# 7          1         0                           Andrews, Mr. Thomas Jr
# 8          1         1    Appleton, Mrs. Edward Dale (Charlotte Lamson)
# 9          1         0                          Artagaveytia, Mr. Ramon
# ...      ...       ...                                              ...
# 1286       3         1  Whabee, Mrs. George Joseph (Shawneene Abi-Saab)
# 1287       3         0                 Widegren, Mr. Carl/Charles Peter
# 1290       3         1                 Wilkes, Mrs. James (Ellen Needs)
# 1298       3         0                        Wittevrongel, Mr. Camille
# 1301       3         0                             Youseff, Mr. Gerious
#
#          sex   age  sibsp  parch    ticket     fare cabin embarked boat  \
# ...

# %% [markdown]
# Problem 16.Select all female passenger with age equal to and more than 35 years

# %%
titanic.loc[(titanic['age']>=35)&(titanic['sex']=='female')]
# Out:
#       pclass  survived                                              name  \
# 6          1         1                 Andrews, Miss. Kornelia Theodosia
# 8          1         1     Appleton, Mrs. Edward Dale (Charlotte Lamson)
# 17         1         1   Baxter, Mrs. James (Helene DeLaudeniere Chaput)
# 21         1         1  Beckwith, Mrs. Richard Leonard (Sallie Monypeny)
# 23         1         1                             Bidois, Miss. Rosalie
# ...      ...       ...                                               ...
# 1158       3         0          Rosblom, Mrs. Viktor (Helena Wilhelmina)
# 1211       3         0   Skoog, Mrs. William (Anna Bernhardina Karlsson)
# 1261       3         1                            Turkula, Mrs. (Hedwig)
# 1286       3         1   Whabee, Mrs. George Joseph (Shawneene Abi-Saab)
# 1290       3         1                  Wilkes, Mrs. James (Ellen Needs)
#
#          sex   age  sibsp  parch    ticket      fare    cabin embarked boat  \
# ...
